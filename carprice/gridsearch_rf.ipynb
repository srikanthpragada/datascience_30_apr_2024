# %%
# import pandas library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Search for best hyperparameters using GridSearchCV and RandomForestRegressor

# %%
cars = pd.read_csv("final_cars.csv")

# %%
## create X and Y
y = cars['price']
X = cars.drop(columns=['price'])

# %%
X = pd.get_dummies(X)

# %%
X.shape
# Out:
# (201, 38)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Set aside some data for testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=99)

# %%
model = RandomForestRegressor()
params_grid  = [{'n_estimators' : [10, 20, 30, 50] , 'max_depth' :[2, 3, 4, 8, 10]}]

# %%
grid_search = GridSearchCV(model, params_grid, cv = 5)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_depth': [2, 3, 4, 8, 10],
#                           'n_estimators': [10, 20, 30, 50]}])

# %%
## display scores 
results = grid_search.cv_results_
for score,param in zip(results['mean_test_score'], results['params']):
      print(score,param)
# Out:
# 0.8388316620595724 {'max_depth': 2, 'n_estimators': 10}
# 0.834833093869031 {'max_depth': 2, 'n_estimators': 20}
# 0.8364559769136545 {'max_depth': 2, 'n_estimators': 30}
# 0.8376425587872127 {'max_depth': 2, 'n_estimators': 50}
# 0.8322928892370971 {'max_depth': 3, 'n_estimators': 10}
# 0.8524420544675948 {'max_depth': 3, 'n_estimators': 20}
# 0.8420202367699492 {'max_depth': 3, 'n_estimators': 30}
# 0.856657288317997 {'max_depth': 3, 'n_estimators': 50}
# 0.8634019341818385 {'max_depth': 4, 'n_estimators': 10}
# 0.8337352238692102 {'max_depth': 4, 'n_estimators': 20}
# 0.8610117480101502 {'max_depth': 4, 'n_estimators': 30}
# 0.85164614040406 {'max_depth': 4, 'n_estimators': 50}
# 0.8641517893343137 {'max_depth': 8, 'n_estimators': 10}
# 0.8353466676120446 {'max_depth': 8, 'n_estimators': 20}
# 0.866030226462204 {'max_depth': 8, 'n_estimators': 30}
# 0.8586351104777451 {'max_depth': 8, 'n_estimators': 50}
# 0.8591823912415378 {'max_depth': 10, 'n_estimators': 10}
# 0.8778614061652104 {'max_depth': 10, 'n_estimators': 20}
# 0.8633927800622336 {'max_depth': 10, 'n_estimators': 30}
# 0.8671381356570175 {'max_depth': 10, 'n_estimators': 50}

# %%
grid_search.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 20}

# %%
grid_search.best_score_
# Out:
# 0.8778614061652104

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=20)

# %% [markdown]
# ### Build model with best estimator

# %%
model = grid_search.best_estimator_

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test,y_pred)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9429871190637437

# %%
np.sqrt(mse)
# Out:
# 2242.107587987416

# %%
# Compare actual and predicted values
plt.gcf().set_size_inches(20,10)
sns.lineplot( y = y_test, x = X_test.index, label="Actual")
sns.lineplot( y = y_pred, x = X_test.index, label="Predicted")
# Out:
# <Axes: ylabel='price'>
